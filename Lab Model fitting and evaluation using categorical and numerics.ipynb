# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import minmax_scale
from sklearn.preprocessing import OneHotEncoder  ##. better to use dummy from pandas 
from sklearn.preprocessing import PowerTransformer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
pd.options.display.max_rows = 50

# %%
Data = pd.read_csv('/Users/divi/Documents/GitHub/DSIronLab/Customer_Analysis_Case_Study/Data/Data_Marketing_Customer_Analysis_Round3.csv')
Data
# Out:
#             region  customer_lifetime_value response  coverage education  \
# 0          central                     4809       no     basic   college
# 1      west region                     2228       no     basic   college
# 2             east                    14947       no     basic  bachelor
# 3       north west                    22332      yes  extended   college
# 4       north west                     9025       no   premium  bachelor
# ...            ...                      ...      ...       ...       ...
# 10684      central                    15563       no   premium  bachelor
# 10685   north west                     5259       no     basic   college
# 10686      central                    23893       no  extended  bachelor
# 10687  west region                    11971       no   premium   college
# 10688      central                     6857       no     basic  bachelor
#
#       effective_to_date month employment_status gender  income  ...  \
# ...

# %%
Categorical = Data.select_dtypes(include=object)
Categorical
# Out:
#             region response  coverage education effective_to_date month  \
# 0          central       no     basic   college           2/18/11   feb
# 1      west region       no     basic   college           1/18/11   jan
# 2             east       no     basic  bachelor           2/10/11   feb
# 3       north west      yes  extended   college           1/11/11   jan
# 4       north west       no   premium  bachelor           1/17/11   jan
# ...            ...      ...       ...       ...               ...   ...
# 10684      central       no   premium  bachelor           1/19/11   jan
# 10685   north west       no     basic   college            1/6/11   jan
# 10686      central       no  extended  bachelor            2/6/11   feb
# 10687  west region       no   premium   college           2/13/11   feb
# 10688      central       no     basic  bachelor            1/8/11   jan
#
#       employment_status gender location_code marital_status     policy_type  \
# ...

# %%
dummy = pd.get_dummies(Categorical, drop_first=True)

# %%
Numerical = Data.select_dtypes(np.number)
Numerical
# Out:
#        customer_lifetime_value  income  monthly_premium_auto  \
# 0                         4809   48029                    61
# 1                         2228   92260                    64
# 2                        14947   22139                   100
# 3                        22332   49078                    97
# 4                         9025   23675                   117
# ...                        ...     ...                   ...
# 10684                    15563   61541                   253
# 10685                     5259   61146                    65
# 10686                    23893   39837                   201
# 10687                    11971   64195                   158
# 10688                     6857   68942                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# 0                            7                             52
# 1                            3                             26
# ...

# %% [markdown]
# #### Concatenating numerical and categorical and then splitting as u and v

# %%
New_df = pd.concat([dummy, Numerical], axis=1)

# %% [markdown]
# ### Performing Test-train split

# %%
X=New_df.drop('total_claim_amount', axis=1)
y=New_df.total_claim_amount

# %%
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=.30,random_state=42)#returns 4 variables, Y is the target variable and the rest independent columns as X

# %% [markdown]
# #### standardising the train set and then transforming it

# %%
std_scaler=StandardScaler().fit(X_train)   ##. finding the parameters ( mean, variance from the training set )

X_train_scaled=std_scaler.transform(X_train)

# %%
x_train.shape
# Out:
# (7482,)

# %% [markdown]
# ##### standardizing the test set

# %%
X_test_scaled=std_scaler.transform(X_test)

# %% [markdown]
# #### printing the train and test test that has been scaled

# %%
print(X_train_scaled)
print("--------")
print(X_test_scaled)
# Out:
# [[-0.3050584  -0.62237768 -0.73429522 ...  1.49683921  0.68183709
#   -0.41232904]
#  [-0.3050584  -0.62237768 -0.73429522 ... -0.5121996  -0.41999987
#   -0.82917079]
#  [-0.3050584   1.60674142 -0.73429522 ...  1.71209337 -0.41999987
#   -0.82917079]
#  ...
#  [-0.3050584  -0.62237768  1.36185008 ... -1.44496762  3.98734797
#    2.08872151]
#  [-0.3050584   1.60674142 -0.73429522 ...  1.49683921 -0.41999987
#   -0.41232904]
#  [-0.3050584  -0.62237768 -0.73429522 ...  0.20531426 -0.41999987
#    1.67187975]]
# --------
# [[-0.3050584  -0.62237768 -0.73429522 ...  1.06633089 -0.41999987
#    0.83819624]
#  [-0.3050584  -0.62237768 -0.73429522 ...  1.06633089 -0.41999987
#    0.00451272]
#  [-0.3050584  -0.62237768  1.36185008 ... -0.11756698 -0.41999987
#   -0.82917079]
#  ...
#  [-0.3050584  -0.62237768 -0.73429522 ...  0.27706565 -0.41999987
#   -0.82917079]
#  [-0.3050584  -0.62237768  1.36185008 ...  0.06181149  0.68183709
#   -0.82917079]
# ...

# %% [markdown]
# #### Applying Linear Regression to

# %%
# Train set
X_train_const_scaled = sm.add_constant(X_train_scaled) # states that we are fitting to the model y=mx+b rather than y=mx.
model = sm.OLS(y_train, X_train_const_scaled).fit() # creating a linear regression model y=mx+b, and fitting it to the train data.
predictions_train = model.predict(X_train_const_scaled)

# %%
# Test set
X_test_const_scaled = sm.add_constant(X_test_scaled) # adding a constant
predictions_test = model.predict(X_test_const_scaled)

# %% [markdown]
# ###### Printing model summary:

# %%
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:     total_claim_amount   R-squared:                       0.768
# Model:                            OLS   Adj. R-squared:                  0.765
# Method:                 Least Squares   F-statistic:                     232.9
# Date:                Thu, 10 Nov 2022   Prob (F-statistic):               0.00
# Time:                        17:08:49   Log-Likelihood:                -47672.
# No. Observations:                7482   AIC:                         9.556e+04
# Df Residuals:                    7376   BIC:                         9.629e+04
# Df Model:                         105
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        433.3067      1.648    262.922      0.000     430.076     436.537
# ...

# %%
print(model.rsquared_adj)
# Out:
# 0.7649956529531782

# %%
print(model.rsquared)
# Out:
# 0.768294069801182
