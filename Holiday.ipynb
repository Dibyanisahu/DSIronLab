# %% [markdown]
# # The beautiful trip

# %% [markdown]
# ###### Her name is Dorothy Perkins. She lives in Thailand. I visited her last month. She took me to this amazing countryside village. It had the magnificient backdrop of sea and sunset. Here is a short video of the place.

# %%
name = input('What is her name?')
# Out:
# What is her name?Dorothy Perkins

# %%
print(name)
# Out:
# Dorothy Perkins

# %% [markdown]
# [VIDEO](#VIDEO)

# %% [markdown]
# ### A small clip is attached below.

# %%
from IPython.display import YouTubeVideo

# %%
video = YouTubeVideo("jCJEx6S2Igo")

# %%
display(video)

# %% [markdown]
# #### The picture shown below is from our trip.

# %% [markdown]
# [IMAGE](#IMAGE)

# %% [markdown]
# ![![20220530_115943.jpeg](attachment:20220530_115943.jpeg)

# %% [markdown]
# # *FAVOURITE SPORTS*

# %% [markdown]
# - Our Fav sports were:
#     -  paddleboard
#     -  surfing
#     -  Swimming

# %% [markdown]
# <font color=RED> COLORS ARE FUN </font>

# %% [markdown]
# ### Activities available in the beach: Use the link below

# %% [markdown]
# [blue_text](https://traveltriangle.com/blog/water-sports-in-thailand/)

# %% [markdown]
# ### Annotations used:

# %% [markdown]
# #### input : to ask user for information;
# ####  "##" for headings "###" for subheadings;
# ####  "-Space" Text : for bullets
