# %%
import numpy as np
import pandas as pd

# %%
file1 = pd.read_csv('Data/file1.csv')
file1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
file2 = pd.read_csv('Data/file2.csv')
file2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
file2.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#       dtype='object')

# %%
file3 = pd.read_csv('Data/file3.csv')

# %%
file3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
print(file1.columns, file2.columns, file3.columns)
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object') Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#       dtype='object') Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
file3 = file3.rename(columns={"Gender":"GENDER","State": "ST"})
file3
# Out:
#      Customer          ST  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      GENDER  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
CA_df = pd.concat([file1,file2,file3])

# %%
CA_df
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
CA_df.dtypes
# Out:
# Customer                      object
# ST                            object
# GENDER                        object
# Education                     object
# Customer Lifetime Value       object
# Income                       float64
# Monthly Premium Auto         float64
# Number of Open Complaints     object
# Policy Type                   object
# Vehicle Class                 object
# Total Claim Amount           float64
# dtype: object

# %%
CA_df = CA_df.drop_duplicates()

# %%
CA_df
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
CA_df = CA_df.drop('Customer', axis=1)

# %%
CA_df
# Out:
#               ST GENDER             Education Customer Lifetime Value  \
# 0     Washington    NaN                Master                     NaN
# 1        Arizona      F              Bachelor              697953.59%
# 2         Nevada      F              Bachelor             1288743.17%
# 3     California      M              Bachelor              764586.18%
# 4     Washington      M  High School or Below              536307.65%
# ...          ...    ...                   ...                     ...
# 7065  California      M              Bachelor             23405.98798
# 7066  California      F               College             3096.511217
# 7067  California      M              Bachelor             8163.890428
# 7068  California      M               College             7524.442436
# 7069  California      M               College             2611.836866
#
#        Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# ...

# %%
CA_df.dtypes
# Out:
# ST                            object
# GENDER                        object
# Education                     object
# Customer Lifetime Value       object
# Income                       float64
# Monthly Premium Auto         float64
# Number of Open Complaints     object
# Policy Type                   object
# Vehicle Class                 object
# Total Claim Amount           float64
# dtype: object

# %%
CA_df["Customer Lifetime Value"] =CA_df["Customer Lifetime Value"].apply(lambda x: float(x.rstrip(x[-1]))/100 if str(x).endswith("%") else x)

# %%
CA_df
# Out:
#               ST GENDER             Education  Customer Lifetime Value  \
# 0     Washington    NaN                Master                      NaN
# 1        Arizona      F              Bachelor              6979.535900
# 2         Nevada      F              Bachelor             12887.431700
# 3     California      M              Bachelor              7645.861800
# 4     Washington      M  High School or Below              5363.076500
# ...          ...    ...                   ...                      ...
# 7065  California      M              Bachelor             23405.987980
# 7066  California      F               College              3096.511217
# 7067  California      M              Bachelor              8163.890428
# 7068  California      M               College              7524.442436
# 7069  California      M               College              2611.836866
#
#        Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# ...

# %%
#CA_df['Customer Lifetime Value'] = CA_df['Customer Lifetime Value'].replace(np.nan, 0)

# %%
#CA_df

# %%
CA_df.dtypes
# Out:
# ST                            object
# GENDER                        object
# Education                     object
# Customer Lifetime Value      float64
# Income                       float64
# Monthly Premium Auto         float64
# Number of Open Complaints     object
# Policy Type                   object
# Vehicle Class                 object
# Total Claim Amount           float64
# dtype: object

# %%
CA_df['Customer Lifetime Value'] = pd.to_numeric(CA_df['Customer Lifetime Value'])

# %%
CA_df.dtypes
# Out:
# ST                            object
# GENDER                        object
# Education                     object
# Customer Lifetime Value      float64
# Income                       float64
# Monthly Premium Auto         float64
# Number of Open Complaints     object
# Policy Type                   object
# Vehicle Class                 object
# Total Claim Amount           float64
# dtype: object

# %%
#CA_df["Customer Lifetime Value"] = CA_df["Customer Lifetime Value"].apply(np.int64)
#print(CA_df.dtypes)

# %%
CA_df
# Out:
#               ST GENDER             Education  Customer Lifetime Value  \
# 0     Washington    NaN                Master                      NaN
# 1        Arizona      F              Bachelor              6979.535900
# 2         Nevada      F              Bachelor             12887.431700
# 3     California      M              Bachelor              7645.861800
# 4     Washington      M  High School or Below              5363.076500
# ...          ...    ...                   ...                      ...
# 7065  California      M              Bachelor             23405.987980
# 7066  California      F               College              3096.511217
# 7067  California      M              Bachelor              8163.890428
# 7068  California      M               College              7524.442436
# 7069  California      M               College              2611.836866
#
#        Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# ...

# %%
print(CA_df['ST'].unique())
# Out:
# ['Washington' 'Arizona' 'Nevada' 'California' 'Oregon' 'Cali' 'AZ' 'WA'
#  nan]

# %%
print(CA_df['GENDER'].unique())
# Out:
# [nan 'F' 'M' 'Femal' 'Male' 'female']

# %%
print(CA_df['Number of Open Complaints'].unique())
# Out:
# ['1/0/00' '1/2/00' '1/1/00' '1/3/00' '1/5/00' '1/4/00' nan 0 2 3 1 5 4]

# %%
l = '1/2/00'

# %%
l[2]
# Out:
# '2'

# %%
def RenameState(ST):
    if ST == "Cali":
        return "California"
    elif ST == "AZ":
        return "Arizona"
    elif ST == "WA":
        return "Washington"
    elif ST == np.nan:
        pass
    else:
        return ST

# %%
CA_df['ST'] = CA_df['ST'].apply(RenameState)

# %%
CA_df
# Out:
#               ST GENDER             Education  Customer Lifetime Value  \
# 0     Washington    NaN                Master                      NaN
# 1        Arizona      F              Bachelor              6979.535900
# 2         Nevada      F              Bachelor             12887.431700
# 3     California      M              Bachelor              7645.861800
# 4     Washington      M  High School or Below              5363.076500
# ...          ...    ...                   ...                      ...
# 7065  California      M              Bachelor             23405.987980
# 7066  California      F               College              3096.511217
# 7067  California      M              Bachelor              8163.890428
# 7068  California      M               College              7524.442436
# 7069  California      M               College              2611.836866
#
#        Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# ...

# %%
print(CA_df['ST'].unique())
# Out:
# ['Washington' 'Arizona' 'Nevada' 'California' 'Oregon' nan]

# %%
def cleanGender(GENDER):
    if GENDER == "Femal":
        return "F"
    elif GENDER == "Male":
        return "M"
    elif GENDER == "female":
        return "F"
    elif GENDER == np.nan:
        pass
    else:
        return GENDER

# %%
CA_df['GENDER'] = CA_df['GENDER'].apply(cleanGender)

# %%
CA_df
# Out:
#               ST GENDER             Education  Customer Lifetime Value  \
# 0     Washington    NaN                Master                      NaN
# 1        Arizona      F              Bachelor              6979.535900
# 2         Nevada      F              Bachelor             12887.431700
# 3     California      M              Bachelor              7645.861800
# 4     Washington      M  High School or Below              5363.076500
# ...          ...    ...                   ...                      ...
# 7065  California      M              Bachelor             23405.987980
# 7066  California      F               College              3096.511217
# 7067  California      M              Bachelor              8163.890428
# 7068  California      M               College              7524.442436
# 7069  California      M               College              2611.836866
#
#        Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# ...

# %%
print(CA_df['GENDER'].unique())
# Out:
# [nan 'F' 'M']

# %%
print(CA_df['Number of Open Complaints'].unique())
# Out:
# ['1/0/00' '1/2/00' '1/1/00' '1/3/00' '1/5/00' '1/4/00' nan 0 2 3 1 5 4]

# %%
# def complaint(string):
   # if len(string) == 1:
#        return string

  #  elif len(string) % 2 == 0:
     #   return string[(len(string) - 1) // 2]
   # else:
    #    return string[len(string) // 2]

# %%
#CA_df['Number of Open Complaints'] = CA_df['Number of Open Complaints'].apply(complaint)

# %%
CA_df["Number of Open Complaints"] = CA_df["Number of Open Complaints"].apply(lambda x: int(x[2]) if type(x)==str and len(x)>1 else x)

# %%
print(CA_df.dtypes)
# Out:
# ST                            object
# GENDER                        object
# Education                     object
# Customer Lifetime Value      float64
# Income                       float64
# Monthly Premium Auto         float64
# Number of Open Complaints    float64
# Policy Type                   object
# Vehicle Class                 object
# Total Claim Amount           float64
# dtype: object

# %%
CA_df['Number of Open Complaints'].value_counts()
# Out:
# 0.0    7252
# 1.0    1012
# 2.0     376
# 3.0     290
# 4.0     148
# 5.0      56
# Name: Number of Open Complaints, dtype: int64

# %%
print(CA_df['Number of Open Complaints'].unique())
# Out:
# [ 0.  2.  1.  3.  5.  4. nan]

# %%
#CA_df2 = CA_df.dropna(axis=0)

# %%
CA_df2.dtypes
# Out:
# index                          int64
# ST                            object
# GENDER                        object
# Education                     object
# Customer Lifetime Value      float64
# Income                       float64
# Monthly Premium Auto         float64
# Number of Open Complaints      int64
# Policy Type                   object
# Vehicle Class                 object
# Total Claim Amount           float64
# mean_income                  float64
# dtype: object

# %%
CA_df["Number of Open Complaints"].unique()
# Out:
# array([ 0.,  2.,  1.,  3.,  5.,  4., nan])

# %%
CA_df["Number of Open Complaints"].value_counts()
# Out:
# 0.0    7252
# 1.0    1012
# 2.0     376
# 3.0     290
# 4.0     148
# 5.0      56
# Name: Number of Open Complaints, dtype: int64

# %%
CA_df["Number of Open Complaints"] = CA_df["Number of Open Complaints"].fillna(0)

# %%
CA_df["Number of Open Complaints"]=CA_df["Number of Open Complaints"].astype(int)

# %%
CA_df
# Out:
#               ST GENDER             Education  Customer Lifetime Value  \
# 0     Washington    NaN                Master                      NaN
# 1        Arizona      F              Bachelor              6979.535900
# 2         Nevada      F              Bachelor             12887.431700
# 3     California      M              Bachelor              7645.861800
# 4     Washington      M  High School or Below              5363.076500
# ...          ...    ...                   ...                      ...
# 7065  California      M              Bachelor             23405.987980
# 7066  California      F               College              3096.511217
# 7067  California      M              Bachelor              8163.890428
# 7068  California      M               College              7524.442436
# 7069  California      M               College              2611.836866
#
#        Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
CA_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9135 entries, 0 to 7069
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ST                         9134 non-null   object
#  1   GENDER                     9012 non-null   object
#  2   Education                  9134 non-null   object
#  3   Customer Lifetime Value    9127 non-null   float64
#  4   Income                     9134 non-null   float64
#  5   Monthly Premium Auto       9134 non-null   float64
#  6   Number of Open Complaints  9135 non-null   int64
#  7   Policy Type                9134 non-null   object
#  8   Vehicle Class              9134 non-null   object
#  9   Total Claim Amount         9134 non-null   float64
# dtypes: float64(4), int64(1), object(5)
# memory usage: 785.0+ KB

# %%
CA_df2 = CA_df.reset_index()

# %%
# to truncate the slashes in number of complaints colm.

# %%
#CA_df['Number of Open Complaints'] = CA_df['Number of Open Complaints'].apply(lambda x: str(x).split("/")[1] if len(str(x).split("/")) > 1 else x)

# %%
CA_df = CA_df2

# %%
CA_df.dtypes
# Out:
# index                          int64
# ST                            object
# GENDER                        object
# Education                     object
# Customer Lifetime Value      float64
# Income                       float64
# Monthly Premium Auto         float64
# Number of Open Complaints      int64
# Policy Type                   object
# Vehicle Class                 object
# Total Claim Amount           float64
# dtype: object

# %%
#CA_df['Customer Lifetime Value'] = (CA_df['Customer Lifetime Value'].str.replace('%', '' and / 100)). apply(np.int64)

# %%
CA_df["Customer Lifetime Value"] =CA_df["Customer Lifetime Value"].apply(lambda x: float(x.rstrip(x[-1]))/100 if str(x).endswith("%") else x)

# %%
CA_df2 = CA_df

# %%
CA_df
# Out:
#       index          ST GENDER             Education  Customer Lifetime Value  \
# 0         0  Washington    NaN                Master                      NaN
# 1         1     Arizona      F              Bachelor              6979.535900
# 2         2      Nevada      F              Bachelor             12887.431700
# 3         3  California      M              Bachelor              7645.861800
# 4         4  Washington      M  High School or Below              5363.076500
# ...     ...         ...    ...                   ...                      ...
# 9130   7065  California      M              Bachelor             23405.987980
# 9131   7066  California      F               College              3096.511217
# 9132   7067  California      M              Bachelor              8163.890428
# 9133   7068  California      M               College              7524.442436
# 9134   7069  California      M               College              2611.836866
#
# ...

# %%
CA_df.dtypes
# Out:
# index                          int64
# ST                            object
# GENDER                        object
# Education                     object
# Customer Lifetime Value      float64
# Income                       float64
# Monthly Premium Auto         float64
# Number of Open Complaints      int64
# Policy Type                   object
# Vehicle Class                 object
# Total Claim Amount           float64
# dtype: object

# %%
CA_df
# Out:
#       index          ST GENDER             Education  Customer Lifetime Value  \
# 0         0  Washington    NaN                Master                      NaN
# 1         1     Arizona      F              Bachelor              6979.535900
# 2         2      Nevada      F              Bachelor             12887.431700
# 3         3  California      M              Bachelor              7645.861800
# 4         4  Washington      M  High School or Below              5363.076500
# ...     ...         ...    ...                   ...                      ...
# 9130   7065  California      M              Bachelor             23405.987980
# 9131   7066  California      F               College              3096.511217
# 9132   7067  California      M              Bachelor              8163.890428
# 9133   7068  California      M               College              7524.442436
# 9134   7069  California      M               College              2611.836866
#
# ...

# %%
CA_df["mean_income"] = CA_df["Income"].mean()

# %%
CA_df
# Out:
#       index          ST GENDER             Education  Customer Lifetime Value  \
# 0         0  Washington    NaN                Master                      NaN
# 1         1     Arizona      F              Bachelor              6979.535900
# 2         2      Nevada      F              Bachelor             12887.431700
# 3         3  California      M              Bachelor              7645.861800
# 4         4  Washington      M  High School or Below              5363.076500
# ...     ...         ...    ...                   ...                      ...
# 9130   7065  California      M              Bachelor             23405.987980
# 9131   7066  California      F               College              3096.511217
# 9132   7067  California      M              Bachelor              8163.890428
# 9133   7068  California      M               College              7524.442436
# 9134   7069  California      M               College              2611.836866
#
# ...

# %%
CA_df["Income"] = CA_df["Income"].fillna(0)

# %%
CA_df["Income"].replace(to_replace = 0, value = 37824.847055, inplace=True)

# %%
CA_df
# Out:
#       index          ST GENDER             Education  Customer Lifetime Value  \
# 0         0  Washington    NaN                Master                      NaN
# 1         1     Arizona      F              Bachelor              6979.535900
# 2         2      Nevada      F              Bachelor             12887.431700
# 3         3  California      M              Bachelor              7645.861800
# 4         4  Washington      M  High School or Below              5363.076500
# ...     ...         ...    ...                   ...                      ...
# 9130   7065  California      M              Bachelor             23405.987980
# 9131   7066  California      F               College              3096.511217
# 9132   7067  California      M              Bachelor              8163.890428
# 9133   7068  California      M               College              7524.442436
# 9134   7069  California      M               College              2611.836866
#
# ...

# %%
CA_df["Customer Lifetime Value"].mean()
# Out:
# 7977.832132374479

# %%
CA_df["Customer Lifetime Value"] = CA_df["Customer Lifetime Value"].replace(np.nan, 7977.832)

# %%
CA_df
# Out:
#       index          ST GENDER             Education  Customer Lifetime Value  \
# 0         0  Washington    NaN                Master              7977.832000
# 1         1     Arizona      F              Bachelor              6979.535900
# 2         2      Nevada      F              Bachelor             12887.431700
# 3         3  California      M              Bachelor              7645.861800
# 4         4  Washington      M  High School or Below              5363.076500
# ...     ...         ...    ...                   ...                      ...
# 9130   7065  California      M              Bachelor             23405.987980
# 9131   7066  California      F               College              3096.511217
# 9132   7067  California      M              Bachelor              8163.890428
# 9133   7068  California      M               College              7524.442436
# 9134   7069  California      M               College              2611.836866
#
# ...

# %%
def replace_state(ST):
     if ST == "California":
        return "West Region"
     elif ST == "Arizona":
        return "Central"
     elif ST == "Nevada":
        return "Central"
     elif ST == "Washington":
        return "East"
     elif ST == "Oregon":
        return "North West"
     else:
        return ST

# %%
CA_df['ST'] = CA_df['ST'].apply(replace_state)

# %%
# Another way of replacing ST with regions
# CA_df["ST"] = CA_df["ST"].apply(lambda x: replace_state(x))

# %%
CA_df
# Out:
#       index           ST GENDER             Education  \
# 0         0         East    NaN                Master
# 1         1      Central      F              Bachelor
# 2         2      Central      F              Bachelor
# 3         3  West Region      M              Bachelor
# 4         4         East      M  High School or Below
# ...     ...          ...    ...                   ...
# 9130   7065  West Region      M              Bachelor
# 9131   7066  West Region      F               College
# 9132   7067  West Region      M              Bachelor
# 9133   7068  West Region      M               College
# 9134   7069  West Region      M               College
#
#       Customer Lifetime Value        Income  Monthly Premium Auto  \
# 0                 7977.832000  37824.847055                1000.0
# 1                 6979.535900  37824.847055                  94.0
# 2                12887.431700  48767.000000                 108.0
# ...

# %%
CA_df['ST'] = CA_df['ST'].apply(replace_state)

# %%
CA_df["ST"].unique()
# Out:
# array(['East', 'Central', 'West Region', 'North West', nan], dtype=object)

# %%
CA_df["Number of Open Complaints"].unique()
# Out:
# array([0, 2, 1, 3, 5, 4])

# %%
check_for_nan = CA_df["Number of Open Complaints"].isnull().values.any()
print (check_for_nan)
# Out:
# False

# %%
check_for_nan = CA_df["Customer Lifetime Value"].isnull().values.any()
print (check_for_nan)
# Out:
# False

# %%
check_for_nan = CA_df["Income"].isnull().values.any()
print (check_for_nan)
# Out:
# False

# %%
check_for_nan = CA_df["Total Claim Amount"].isnull().values.any()
print (check_for_nan)
# Out:
# True

# %%
CA_df["Total Claim Amount"].mean()
# Out:
# 430.4804115177334

# %%
CA_df["Total Claim Amount"] = CA_df["Total Claim Amount"].replace(np.nan, 430.48)

# %%
check_for_nan = CA_df["Monthly Premium Auto"].isnull().values.any()
print (check_for_nan)
# Out:
# True

# %%
CA_df["Monthly Premium Auto"].mean()
# Out:
# 110.39314648565798

# %%
CA_df["Monthly Premium Auto"] = CA_df["Monthly Premium Auto"].replace(np.nan, 110.39)

# %%
def merge_car(x):
    if x in ["Luxury SUV", "Luxury Car"]:
        return "Luxury Vehicle"
    else:
        return x

# %%
CA_df["Vehicle Class"]=list(map(merge_car, CA_df["Vehicle Class"]))

# %%
CA_df["Vehicle Class"].unique()
# Out:
# array(['Four-Door Car', 'Two-Door Car', 'SUV', 'Luxury Vehicle',
#        'Sports Car', nan], dtype=object)

# %%
CA_df=CA_df.drop(columns=["mean_income"], axis = 1)
CA_df
# Out:
#       index           ST GENDER             Education  \
# 0         0         East    NaN                Master
# 1         1      Central      F              Bachelor
# 2         2      Central      F              Bachelor
# 3         3  West Region      M              Bachelor
# 4         4         East      M  High School or Below
# ...     ...          ...    ...                   ...
# 9130   7065  West Region      M              Bachelor
# 9131   7066  West Region      F               College
# 9132   7067  West Region      M              Bachelor
# 9133   7068  West Region      M               College
# 9134   7069  West Region      M               College
#
#       Customer Lifetime Value        Income  Monthly Premium Auto  \
# 0                 7977.832000  37824.847055                1000.0
# 1                 6979.535900  37824.847055                  94.0
# 2                12887.431700  48767.000000                 108.0
# ...

# %%
CA_df.describe()
# Out:
#              index  Customer Lifetime Value        Income  \
# count  9135.000000              9135.000000   9135.000000
# mean   2852.597482              7977.832132  47323.500492
# std    2199.222758              6807.207533  21726.098915
# min       0.000000              1898.007675  10037.000000
# 25%     762.000000              3981.978294  34357.500000
# 50%    2502.000000              5768.830622  37824.847055
# 75%    4785.500000              8928.588468  62446.000000
# max    7069.000000             83325.381190  99981.000000
#
#        Monthly Premium Auto  Number of Open Complaints  Total Claim Amount
# count           9135.000000                9135.000000         9135.000000
# mean             110.393146                   0.383799          430.480411
# std              581.439630                   0.909069          289.602131
# min               61.000000                   0.000000            0.099007
# ...

# %%
arr=CA_df['Customer Lifetime Value']

def outlier_treatment(customer_lifetime):
    arr.sort_values
    Q1 = np.percentile(arr, [25])
    Q3 = np.percentile(arr, [75])
    IQR = Q3-Q1
    lower_range = Q1-(1.5 * IQR)
    upper_range = Q3 + (1.5 * IQR)
    return lower_range,upper_range

# %%
lowerbound,upperbound = outlier_treatment(arr)

# %%
CA_df.drop(CA_df[ (arr > upperbound[0]) | (arr < lowerbound[0]) ].index , inplace=True)

# %%
CA_df
# Out:
#       index           ST GENDER             Education  \
# 0         0         East    NaN                Master
# 1         1      Central      F              Bachelor
# 2         2      Central      F              Bachelor
# 3         3  West Region      M              Bachelor
# 4         4         East      M  High School or Below
# ...     ...          ...    ...                   ...
# 9129   7064  West Region      F               College
# 9131   7066  West Region      F               College
# 9132   7067  West Region      M              Bachelor
# 9133   7068  West Region      M               College
# 9134   7069  West Region      M               College
#
#       Customer Lifetime Value        Income  Monthly Premium Auto  \
# 0                 7977.832000  37824.847055                1000.0
# 1                 6979.535900  37824.847055                  94.0
# 2                12887.431700  48767.000000                 108.0
# ...

# %%
CA_df.dtypes
# Out:
# index                          int64
# ST                            object
# GENDER                        object
# Education                     object
# Customer Lifetime Value      float64
# Income                       float64
# Monthly Premium Auto         float64
# Number of Open Complaints      int64
# Policy Type                   object
# Vehicle Class                 object
# Total Claim Amount           float64
# dtype: object

# %%
Inc=CA_df['Income']

def outlier_treatment(income):
    Inc.sort_values
    Q1 = np.percentile(Inc, [25])
    Q3 = np.percentile(Inc, [75])
    IQR = Q3-Q1
    lower_range = Q1-(1.5 * IQR)
    upper_range = Q3 + (1.5 * IQR)
    return lower_range,upper_range

# %%
lowerbound,upperbound = outlier_treatment(Inc)

# %%
CA_df.drop(CA_df[ (Inc > upperbound[0]) | (Inc < lowerbound[0]) ].index , inplace=True)

# %%
CA_df
# Out:
#       index           ST GENDER             Education  \
# 45       45   North West    NaN                Doctor
# 59       59   North West    NaN                Master
# 61       61  West Region    NaN              Bachelor
# 171     171   North West      F                Doctor
# 211     211  West Region      M               College
# ...     ...          ...    ...                   ...
# 8743   6678  West Region      M  High School or Below
# 8756   6691  West Region      F                Master
# 8767   6702  West Region      F              Bachelor
# 8951   6886  West Region      F              Bachelor
# 9065   7000  West Region      F               College
#
#       Customer Lifetime Value   Income  Monthly Premium Auto  \
# 45               12819.102900  10105.0                 172.0
# 59                4059.567400  11621.0                 108.0
# 61                8110.333100  11489.0                 105.0
# 171              15363.847200  15897.0                 101.0
# ...

# %%
CA_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 277 entries, 45 to 9065
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   index                      277 non-null    int64
#  1   ST                         277 non-null    object
#  2   GENDER                     273 non-null    object
#  3   Education                  277 non-null    object
#  4   Customer Lifetime Value    277 non-null    float64
#  5   Income                     277 non-null    float64
#  6   Monthly Premium Auto       277 non-null    float64
#  7   Number of Open Complaints  277 non-null    int64
#  8   Policy Type                277 non-null    object
#  9   Vehicle Class              277 non-null    object
#  10  Total Claim Amount         277 non-null    float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 26.0+ KB

# %%
Mon_Prem_Auto = CA_df['Monthly Premium Auto']

def outlier_treatment(Monthly_Premium_Auto):
    Inc.sort_values
    Q1 = np.percentile(Mon_Prem_Auto, [25])
    Q3 = np.percentile(Mon_Prem_Auto, [75])
    IQR = Q3-Q1
    lower_range = Q1-(1.5 * IQR)
    upper_range = Q3 + (1.5 * IQR)
    return lower_range,upper_range

# %%
lowerbound,upperbound = outlier_treatment(Mon_Prem_Auto)

# %%
CA_df.drop(CA_df[ (Mon_Prem_Auto > upperbound[0]) | (Mon_Prem_Auto < lowerbound[0]) ].index , inplace=True)

# %%
CA_df
# Out:
#       index           ST GENDER             Education  \
# 45       45   North West    NaN                Doctor
# 59       59   North West    NaN                Master
# 61       61  West Region    NaN              Bachelor
# 171     171   North West      F                Doctor
# 211     211  West Region      M               College
# ...     ...          ...    ...                   ...
# 8743   6678  West Region      M  High School or Below
# 8756   6691  West Region      F                Master
# 8767   6702  West Region      F              Bachelor
# 8951   6886  West Region      F              Bachelor
# 9065   7000  West Region      F               College
#
#       Customer Lifetime Value   Income  Monthly Premium Auto  \
# 45               12819.102900  10105.0                 172.0
# 59                4059.567400  11621.0                 108.0
# 61                8110.333100  11489.0                 105.0
# 171              15363.847200  15897.0                 101.0
# ...

# %% [markdown]
# TCA = CA_df['Total Claim Amount']
#
# def outlier_treatment(Total_Claim_Amount):
#     Inc.sort_values
#     Q1 = np.percentile(arr, [25])
#     Q3 = np.percentile(arr, [75])
#     IQR = Q3-Q1
#     lower_range = Q1-(1.5 * IQR)
#     upper_range = Q3 + (1.5 * IQR)
#     return lower_range,upper_range

# %%
#lowerbound,upperbound = outlier_treatment(TCA)

# %%
#CA_df.drop(CA_df[ (TCA > upperbound[0]) | (TCA < lowerbound[0]) ].index , inplace=True)

# %%
CA_df
# Out:
#       index           st gender             education  \
# 45       45   North West    NaN                Doctor
# 59       59   North West    NaN                Master
# 61       61  West Region    NaN              Bachelor
# 171     171   North West      F                Doctor
# 211     211  West Region      M               College
# ...     ...          ...    ...                   ...
# 8743   6678  West Region      M  High School or Below
# 8756   6691  West Region      F                Master
# 8767   6702  West Region      F              Bachelor
# 8951   6886  West Region      F              Bachelor
# 9065   7000  West Region      F               College
#
#       customer lifetime value   income  monthly premium auto  \
# 45               12819.102900  10105.0                 172.0
# 59                4059.567400  11621.0                 108.0
# 61                8110.333100  11489.0                 105.0
# 171              15363.847200  15897.0                 101.0
# ...

# %%
CA_df.columns = [x.lower() for x in CA_df.columns]
CA_df
# Out:
#       index           st gender             education  \
# 45       45   North West    NaN                Doctor
# 59       59   North West    NaN                Master
# 61       61  West Region    NaN              Bachelor
# 171     171   North West      F                Doctor
# 211     211  West Region      M               College
# ...     ...          ...    ...                   ...
# 8743   6678  West Region      M  High School or Below
# 8756   6691  West Region      F                Master
# 8767   6702  West Region      F              Bachelor
# 8951   6886  West Region      F              Bachelor
# 9065   7000  West Region      F               College
#
#       customer lifetime value   income  monthly premium auto  \
# 45               12819.102900  10105.0                 172.0
# 59                4059.567400  11621.0                 108.0
# 61                8110.333100  11489.0                 105.0
# 171              15363.847200  15897.0                 101.0
# ...

# %%
CA_df['education'].unique()
# Out:
# array(['Doctor', 'Master', 'Bachelor', 'College', 'High School or Below'],
#       dtype=object)

# %% [markdown]
# def outliers(df,ft):
#     Q1 = df[ft].quantile(0.25)
#     Q3 = df[ft].quantile(0.75)
#     IQR = Q3 - Q1
#     lower_range = Q1 - (1.5 * IQR)
#     upper_range = Q3 + (1.5 * IQR)
#
#     ls = df.index[(df[ft] < lower_range) | (df[ft] > upper_range)]
#
#     return
#
# index_list = []
# for feature in ['Customer Lifetime Value','Income','Monthly Premium Auto','Number of Open Complaints','Total Claim Amount']:
#     index_list.extend(outliers(CA_df,feature))
#
# index_list
#
# def remove(CA_df,ls):
#     ls = sorted(set(ls))
#     CA_df = CA_df.drop(ls)
#
#     return CA_df
#
# df_cleaned = remove(CA_df,index_list)
# df_cleaned

# %%
CA_df.reset_index()
# Out:
#      level_0  index           st gender             education  \
# 0         45     45   North West    NaN                Doctor
# 1         59     59   North West    NaN                Master
# 2         61     61  West Region    NaN              Bachelor
# 3        171    171   North West      F                Doctor
# 4        211    211  West Region      M               College
# ..       ...    ...          ...    ...                   ...
# 272     8743   6678  West Region      M  High School or Below
# 273     8756   6691  West Region      F                Master
# 274     8767   6702  West Region      F              Bachelor
# 275     8951   6886  West Region      F              Bachelor
# 276     9065   7000  West Region      F               College
#
#      customer lifetime value   income  monthly premium auto  \
# 0               12819.102900  10105.0                 172.0
# 1                4059.567400  11621.0                 108.0
# ...
